# %%
import matplotlib.pyplot as plt
x1 =[5,15]
plt.plot(x1,label = 'rice',marker='o')
x2 =[3,6]
plt.plot(x2,label = 'oil',marker='s')
x3 =[8.0010, 14.2]
plt.plot(x3,label = 'wheat',marker='H')
x4 =[1.95412, 6.98547, 5.41411, 5.99, 7.9999]
plt.plot(x4,label = 'coffee',marker='*')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
