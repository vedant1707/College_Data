# %%
from matplotlib import pyplot as plt
country = ['India', 'Canada', 'Japan','Australia', 'Russia']
data = [31, 19, 15, 14, 21]
plt.pie(data, labels= country, autopct='%1.2f%%')
plt.pie(data, labels = country)
plt.show()
