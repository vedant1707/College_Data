# %%
import matplotlib.pyplot as plt
x1 = [214, 5, 91, 81, 122, 16, 218, 22]
x2 = [12, 125, 149, 198, 22, 26, 28, 32]
plt.plot(x1, 'o',color='orange', markersize=20) 
plt.plot(x2, 'o',color='green', markersize=10)
plt.show()
