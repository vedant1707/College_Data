# %% [markdown]
# # 4.7_1_1

# %%
from skimage.io import imread
from skimage.transform import resize
from matplotlib import pyplot as plt
import matplotlib.cm as cm
ex_file = ("nature.png")
image = imread(ex_file)
plt.imshow(image)
plt.show()

# %% [markdown]
# # 4.7_1_2

# %%
image2 = image[50:500 , 200:500]
plt.imshow(image2)
plt.show()

# %% [markdown]
# # 4.7_1_3

# %%
image3 = resize(image2, (50,50), mode = 'edge')
plt.imshow(image3, cmap = cm.gray)
plt.show()
print("data type: %s , shape: %s" % (type(image),image.shape))
# Out:
# data type: <class 'numpy.ndarray'> , shape: (416, 626, 3)

# %% [markdown]
# # 4.7_1_4

# %%
image_row = image3.flatten()
print("data type: %s , shape: %s" % (type(image_row),image_row.shape))
# Out:
# data type: <class 'numpy.ndarray'> , shape: (7500,)

# %% [markdown]
# # 4.7_2_1

# %%
from skimage.io import imread
from skimage.transform import resize
from matplotlib import pyplot as plt
import matplotlib.cm as cm
ex_file = ("http://www.canmaps.com/topomaps/nts50/toporama/orthoimages/002c04.jpg")
image = imread(ex_file)
plt.imshow(image)
plt.show()

# %% [markdown]
# # 4_7_2_2

# %%
image2 = image[50:700 , 200:1200]
plt.imshow(image2)
plt.show()

# %% [markdown]
# # 4_7_2_3

# %%
image3 = resize(image2, (300,500), mode = 'edge')
plt.imshow(image3, cmap = cm.gray)
plt.show()
print("data type: %s , shape: %s" % (type(image),image.shape))
# Out:
# data type: <class 'numpy.ndarray'> , shape: (800, 1600, 3)

# %% [markdown]
# # 4_7_2_4

# %%
image_row = image3.flatten()
print("data type: %s , shape: %s" % (type(image_row),image_row.shape))
# Out:
# data type: <class 'numpy.ndarray'> , shape: (450000,)
